# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
data=pd.read_csv(r'C:\Users\agisa\Downloads\ML case Study.csv', header = 0)
cities=pd.read_csv(r'C:\Users\agisa\Downloads\cities.csv', header = 0)
college_tier=pd.read_csv(r'C:\Users\agisa\Downloads\Colleges.csv', header = 0)

# %%
data
# Out:
#                           College             City       Role  Previous CTC  \
# 0                     SVNIT Surat          Asansol    Manager       55523.0
# 1                      NIT Bhopal            Ajmer  Executive       57081.0
# 2                    IEM, Kolkata  Rajpur Sonarpur  Executive       60347.0
# 3               KIIT, Bhubaneswar            Ajmer  Executive       49010.0
# 4                             DTU         Durgapur  Executive       57879.0
# ...                           ...              ...        ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat  Executive       61285.0
# 1585                 NIT Warangal  Rajpur Sonarpur  Executive       63140.0
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad  Executive       44907.0
# 1587               IIIT Hyderabad         Durgapur  Executive       52054.0
# 1588  R.V. College of Engineering            Delhi    Manager       44353.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   College              1589 non-null   object
#  1   City                 1589 non-null   object
#  2   Role                 1589 non-null   object
#  3   Previous CTC         1589 non-null   float64
#  4   Previous job change  1589 non-null   int64
#  5   Graduation Marks     1589 non-null   int64
#  6   EXP (Month)          1589 non-null   int64
#  7   CTC                  1589 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 99.4+ KB

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Metrio City       9 non-null      object
#  1   non-metro cities  8 non-null      object
# dtypes: object(2)
# memory usage: 276.0+ bytes

# %%
cities
# Out:
#   Metrio City non-metro cities
# 0      Mumbai         Dehradun
# 1       Delhi         Durgapur
# 2     Kolkata          Asansol
# 3     Chennai         Rourkela
# 4   Bangalore        Kozhikode
# 5   Hyderabad  Rajpur Sonarpur
# 6   Ahmedabad         Kolhapur
# 7        Pune            Ajmer
# 8       Surat              NaN

# %%
college_tier
# Out:
#                             Tier 1                                     Tier 2  \
# 0                       IIT Bombay                             IIIT Bangalore
# 1                        IIT Delhi                                 IIIT Delhi
# 2                    IIT Kharagpur                                     IGDTUW
# 3                       IIT Madras                                NIT Calicut
# 4                       IIT Kanpur                              IIITM Gwalior
# 5                      IIT Roorkee                               IIIT Lucknow
# 6                     IIT Guwahati                            MNNIT Allahabad
# 7                   IIIT Hyderabad                 Punjab Engineering College
# 8      BITS Pilani (Pilani Campus)                                     DAIICT
# 9                       IIT Indore                                MNIT Jaipur
# 10                       IIT Ropar                               NIT Durgapur
# ...

# %%
data.describe()
# Out:
#        Previous CTC  Previous job change  Graduation Marks  EXP (Month)  \
# count   1589.000000          1589.000000       1589.000000  1589.000000
# mean   55518.453744             2.528634         59.855255    39.044682
# std     6655.218445             1.123918         14.935139    14.108875
# min    36990.000000             1.000000         35.000000    18.000000
# 25%    50518.000000             2.000000         46.000000    26.000000
# 50%    55291.000000             3.000000         60.000000    39.000000
# 75%    60109.000000             4.000000         73.000000    51.000000
# max    77911.000000             4.000000         85.000000    64.000000
#
#                  CTC
# count    1589.000000
# mean    75353.278798
# std     12587.288237
# min     53020.320000
# 25%     66902.350000
# 50%     73028.670000
# 75%     80588.670000
# max    123416.990000

# %%
metro = data['City'].isin(cities['Metrio City'])
data['city_type']=0

# %%
data.loc[metro,'city_type']=1

# %%
data
# Out:
#                           College             City       Role  Previous CTC  \
# 0                     SVNIT Surat          Asansol    Manager       55523.0
# 1                      NIT Bhopal            Ajmer  Executive       57081.0
# 2                    IEM, Kolkata  Rajpur Sonarpur  Executive       60347.0
# 3               KIIT, Bhubaneswar            Ajmer  Executive       49010.0
# 4                             DTU         Durgapur  Executive       57879.0
# ...                           ...              ...        ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat  Executive       61285.0
# 1585                 NIT Warangal  Rajpur Sonarpur  Executive       63140.0
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad  Executive       44907.0
# 1587               IIIT Hyderabad         Durgapur  Executive       52054.0
# 1588  R.V. College of Engineering            Delhi    Manager       44353.0
#
# ...

# %%
data
# Out:
#                           College             City       Role  Previous CTC  \
# 0                     SVNIT Surat          Asansol    Manager       55523.0
# 1                      NIT Bhopal            Ajmer  Executive       57081.0
# 2                    IEM, Kolkata  Rajpur Sonarpur  Executive       60347.0
# 3               KIIT, Bhubaneswar            Ajmer  Executive       49010.0
# 4                             DTU         Durgapur  Executive       57879.0
# ...                           ...              ...        ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat  Executive       61285.0
# 1585                 NIT Warangal  Rajpur Sonarpur  Executive       63140.0
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad  Executive       44907.0
# 1587               IIIT Hyderabad         Durgapur  Executive       52054.0
# 1588  R.V. College of Engineering            Delhi    Manager       44353.0
#
# ...

# %% [markdown]
# # Creating Dummies

# %%
data =pd.get_dummies(data, columns=['Role'])

# %%
data.head()
# Out:
#              College             City  Previous CTC  Previous job change  \
# 0        SVNIT Surat          Asansol       55523.0                    3
# 1         NIT Bhopal            Ajmer       57081.0                    1
# 2       IEM, Kolkata  Rajpur Sonarpur       60347.0                    2
# 3  KIIT, Bhubaneswar            Ajmer       49010.0                    2
# 4                DTU         Durgapur       57879.0                    4
#
#    Graduation Marks  EXP (Month)       CTC  city_type  Role_Executive  \
# 0                66           19  71406.58          0           False
# 1                84           18  68005.87          0            True
# 2                52           28  76764.02          0            True
# 3                81           33  82092.39          0            True
# 4                74           32  73878.10          0            True
#
#    Role_Manager
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False

# %%
data['Role_Manager'] = data['Role_Manager'].astype(int)
data['Role_Executive'] = data['Role_Executive'].astype(int)

# %%
data
# Out:
#                           College             City  Previous CTC  \
# 0                     SVNIT Surat          Asansol       55523.0
# 1                      NIT Bhopal            Ajmer       57081.0
# 2                    IEM, Kolkata  Rajpur Sonarpur       60347.0
# 3               KIIT, Bhubaneswar            Ajmer       49010.0
# 4                             DTU         Durgapur       57879.0
# ...                           ...              ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat       61285.0
# 1585                 NIT Warangal  Rajpur Sonarpur       63140.0
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad       44907.0
# 1587               IIIT Hyderabad         Durgapur       52054.0
# 1588  R.V. College of Engineering            Delhi       44353.0
#
#       Previous job change  Graduation Marks  EXP (Month)       CTC  city_type  \
# 0                       3                66           19  71406.58          0
# ...

# %% [markdown]
# # Plotting a Bar graph of count of different Tiers

# %%
sns.countplot(data=data,x='tier')
# Out:
# <Axes: xlabel='tier', ylabel='count'>

# %%
tier = data['College'].isin(college_tier['Tier 3'])
data.loc[tier,'tier']=3

# %% [markdown]
# # Data Standardize

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
columns_to_standardize = ['Previous CTC', 'Graduation Marks', 'EXP (Month)', 'CTC']
X = data[columns_to_standardize]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
data[columns_to_standardize] = X_scaled

# %%
data
# Out:
#                           College             City  Previous CTC  \
# 0                     SVNIT Surat          Asansol      0.000683
# 1                      NIT Bhopal            Ajmer      0.234859
# 2                    IEM, Kolkata  Rajpur Sonarpur      0.725756
# 3               KIIT, Bhubaneswar            Ajmer     -0.978255
# 4                             DTU         Durgapur      0.354803
# ...                           ...              ...           ...
# 1584     BITS Pilani (Goa Campus)            Surat      0.866743
# 1585                 NIT Warangal  Rajpur Sonarpur      1.145559
# 1586    NIT Tiruchipally (Trichy)        Ahmedabad     -1.594958
# 1587               IIIT Hyderabad         Durgapur     -0.520726
# 1588  R.V. College of Engineering            Delhi     -1.678227
#
#       Previous job change  Graduation Marks  EXP (Month)       CTC  city_type  \
# 0                       3          0.411558    -1.421162 -0.313645          0
# ...

# %% [markdown]
# #    # Plotting a scatterplot of Role vs CTC

# %%
sns.scatterplot(data=data, x='Role_Executive', y='CTC')
# Out:
# <Axes: xlabel='Role_Executive', ylabel='CTC'>

# %%
sns.scatterplot(data=data, x='Role_Manager', y='CTC')
# Out:
# <Axes: xlabel='Role_Manager', ylabel='CTC'>

# %% [markdown]
# # Potting a scatter plot of Previous CTC vs CTC

# %%
sns.scatterplot(data=data, x='Previous CTC', y='CTC')
# Out:
# <Axes: xlabel='Previous CTC', ylabel='CTC'>

# %% [markdown]
# # plotting a scatter plot of Tier vs CTC

# %%
sns.scatterplot(data=data, x='tier', y='CTC')
# Out:
# <Axes: xlabel='tier', ylabel='CTC'>

# %% [markdown]
# # Plotting a scatterplot Job changes vs  CTC

# %%
sns.scatterplot(data=data, x='Previous job change', y='CTC')
# Out:
# <Axes: xlabel='Previous job change', ylabel='CTC'>

# %% [markdown]
# # Plotting a scotterplot graduation marks vs CTC

# %%
sns.scatterplot(data=data, x='Graduation Marks', y='CTC')
# Out:
# <Axes: xlabel='Graduation Marks', ylabel='CTC'>

# %% [markdown]
# # x - y split

# %%
x=data.drop(columns=['CTC', 'College', 'City'])

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.head()
# Out:
#    Previous CTC  Previous job change  Graduation Marks  EXP (Month)  \
# 0       55523.0                    3                66           19
# 1       57081.0                    1                84           18
# 2       60347.0                    2                52           28
# 3       49010.0                    2                81           33
# 4       57879.0                    4                74           32
#
#    city_type  Role_Executive  Role_Manager  tier
# 0          0               0             1   2.0
# 1          0               1             0   2.0
# 2          0               1             0   3.0
# 3          0               1             0   3.0
# 4          0               1             0   1.0

# %%
x.shape
# Out:
# (1589, 8)

# %%
y=data['CTC']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0    71406.58
# 1    68005.87
# 2    76764.02
# 3    82092.39
# 4    73878.10
# Name: CTC, dtype: float64

# %%
y.shape
# Out:
# (1589,)

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2 , random_state=0)

# %%
x_train.head()
# Out:
#       Previous CTC  Previous job change  Graduation Marks  EXP (Month)  \
# 1062       61410.0                    4                83           59
# 215        59781.0                    1                46           41
# 654        62521.0                    1                70           59
# 55         66624.0                    1                63           58
# 1187       54621.0                    2                52           62
#
#       city_type  Role_Executive  Role_Manager  tier
# 1062          0               0             1   1.0
# 215           1               1             0   1.0
# 654           0               1             0   1.0
# 55            0               0             1   1.0
# 1187          0               1             0   3.0

# %%
x_train.shape
# Out:
# (1271, 8)

# %%
x_test.shape
# Out:
# (318, 8)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression

# %%
regression_model = LinearRegression()

# %%
regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print(mse)
# Out:
# 68909870.69953667

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 68909870.69953667

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5355989894789346

# %% [markdown]
# # XGboost

# %%
# !pip install xgboost
import xgboost as xgb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 393.8 kB/s eta 0:04:14
#    ---------------------------------------- 0.1/99.8 MB 731.4 kB/s eta 0:02:17
#    ---------------------------------------- 0.2/99.8 MB 952.6 kB/s eta 0:01:45
#    ---------------------------------------- 0.3/99.8 MB 1.2 MB/s eta 0:01:22
#    ---------------------------------------- 0.4/99.8 MB 1.6 MB/s eta 0:01:02
# ...

# %%
import xgboost as xgb

# %%
model=xgb.XGBRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
predicts = model.predict(x_test)

# %%
mse=mean_squared_error(y_test, predicts)

# %%
print(mse)
# Out:
# 57233147.456760116

# %%
r2= r2_score(y_test,predicts)

# %%
r2
# Out:
# 0.6142913744518279

# %% [markdown]
# # 1. Your views about the problem statement?

# %% [markdown]
# The problem statement aims to use regression in machine learning to predict employee salaries at TechWorks Consulting. By leveraging historical data on qualifications, experience, and other factors, the company intends to create a model for fair and consistent compensation decisions. The approach involves preprocessing data, including handling missing values and converting categorical variables, with a focus on statistical analysis. The goal is to automate and improve the accuracy of salary predictions, saving time and ensuring data-driven decision-making. Thorough documentation and iterative data preprocessing are emphasized for transparency and reliability in the model development process.

# %% [markdown]
# # 2. What will be your approach to solving this task?

# %% [markdown]
# 1. Data Understanding
# 2. Data Preprocessing
# 3. Exploratory Data Analysis (EDA)
# 4. Model Selection
# 5. Training and Evaluation
# 6. Optimization
# 7. Reasoning and Documentation
# 8. Prediction and Analysis

# %% [markdown]
# # 3. What were the available ML model options you had to perform this task?

# %% [markdown]
# These are the available
# 1. Linear Regression
# 2. Ridge Regression
# 3. Lasso Regression
# 4. Decision Tree Regression
# 5. Random Forest Regression
# 6. Support Vector Regression (SVR)
# 7. Gradient Boosting Regression
# 8. K-Nearest Neighbors (KNN) Regression
# 9. Neural Network Regression
#
# For this task i used linear regression and xgboost.

# %% [markdown]
# # 4. Which model’s performance is best and what could be the possible reason for that?

# %% [markdown]
# XGBoost offers several advantages over traditional linear regression models. Firstly, XGBoost is a powerful ensemble learning algorithm that can capture complex nonlinear relationships between features and the target variable, whereas linear regression assumes a linear relationship. This makes XGBoost more flexible and capable of handling a wider range of datasets with high dimensionality and intricate patterns. Additionally, XGBoost employs boosting, a sequential ensemble technique, which iteratively improves the model's performance by focusing on the instances that are harder to classify or predict, leading to higher accuracy. Furthermore, XGBoost is less sensitive to outliers and noise compared to linear regression, as it uses decision trees that naturally handle irregularities in the data. Overall, XGBoost's robustness, flexibility, and superior performance in handling nonlinear relationships make it a preferred choice for regression tasks over linear regression models.

# %% [markdown]
# # 5. What steps can you take to improve this selected model’s performance even further?

# %% [markdown]
# To enhance the performance of the selected XGBoost Regression model, several steps can be taken. Firstly, feature engineering can be employed to create new informative features or transform existing ones to better capture the underlying patterns. Secondly, hyperparameter tuning can be conducted to optimize the model parameters for improved accuracy. Additionally, increasing the amount of diverse and relevant training data can enhance the model's generalization capabilities. Feature importance analysis can guide the selection of the most impactful variables. Ensemble methods, combining multiple models, might provide further performance gains. Regularization techniques can be applied to prevent overfitting. Lastly, fine-tuning the learning rate and employing early stopping during training can help achieve optimal convergence and prevent overfitting. Through these steps, the XGBoost model can be refined to better capture the nuances of the salary prediction task.
